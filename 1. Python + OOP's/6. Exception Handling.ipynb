# %% [markdown]
# ## ✅ 6. Exception Handling
#
# - Errors vs Exceptions
# - `try`, `except`, `finally` blocks
# - Multiple exception handling
# - `raise` keyword
#
# ---

# %% [markdown]
# # ✅ 6. Exception Handling
#
# ---
#
# ## 🔸 Errors vs Exceptions
#
# | Concept  | Description |
# |----------|-------------|
# | **Error** | Serious issues (e.g., `SystemError`, `MemoryError`) — usually unrecoverable. |
# | **Exception** | Runtime problems you *can* handle — e.g., `ZeroDivisionError`, `ValueError`, etc. |
#
# Python doesn’t crash on exceptions **if** you handle them.
#
# ---
#
# ## 🔹 `try`, `except`, `finally` Blocks
#
# ### 🔹 Syntax:
# ```python
# try:
#     # risky code
# except SomeException as e:
#     # handling code
# else:
#     # runs if no exception occurs
# finally:
#     # always runs
# ```
#
# ### 🔹 Example:
# ```python
# try:
#     x = 10 / 0
# except ZeroDivisionError as e:
#     print("Error:", e)
# else:
#     print("Success!")
# finally:
#     print("Always executed")
# ```
#
# ### Output:
# ```
# Error: division by zero
# Always executed
# ```
#
# ✅ `else` runs **only** if no error
# ✅ `finally` runs **no matter what** — use it for cleanup, file closing, DB disconnect, etc.
#
# ---
#
# ## 🔹 Multiple Exception Handling
#
# ### 🔹 Syntax:
# ```python
# try:
#     ...
# except (TypeError, ValueError):
#     ...
# except FileNotFoundError as e:
#     ...
# ```
#
# ✅ Group exceptions in a tuple.
# ✅ Use multiple `except` blocks for different handling logic.
#
# ---
#
# ## 🔹 `raise` keyword
#
# ### ➤ Used to manually trigger an exception.
#
# ```python
# raise ValueError("Invalid input")
# ```
#
# ✅ You can re-raise caught exceptions:
# ```python
# try:
#     ...
# except Exception as e:
#     log_error(e)
#     raise  # Re-throws the same exception
# ```
#
# ---
#
# ## 🔹 Custom Exceptions
#
# Create your own exception by subclassing `Exception`:
#
# ```python
# class NegativeNumberError(Exception):
#     pass
#
# def process(num):
#     if num < 0:
#         raise NegativeNumberError("Negative not allowed")
#
# process(-5)
# ```
#
# ---
#
# ## 🧠 Bonus: Best Practices
#
# | Practice | Why |
# |---------|-----|
# | Be specific in `except` | Avoid swallowing bugs |
# | Use `finally` for cleanup | Always runs |
# | Don't silence errors | Always log or re-raise |
# | Prefer `with` statements for file/DB ops | Auto cleanup |
#
# ---
#
# ## 🧪 Example: Full Structure
#
# ```python
# def divide(x, y):
#     try:
#         result = x / y
#     except ZeroDivisionError:
#         return "Can't divide by zero"
#     except TypeError:
#         return "Invalid input types"
#     else:
#         return result
#     finally:
#         print("Operation attempted")
#
# print(divide(10, 0))  # Can't divide by zero
# print(divide(10, 2))  # 5.0
# ```
#
# ---

# %%
def divide(x, y):
    try: 
        result = x/y
    except ZeroDivisionError:
        return "Cant divide by zero"
    except TypeError:
        return "Invalid input types"
    else: 
        return result
    finally:
        print("Operation attended")
        
print(divide(10, 0))
print(divide(10, 2))
# Out:
# Operation attended
# Cant divide by zero
# Operation attended
# 5.0
